# %% [markdown]
# ## Computational Playground (LLL Reduction)
#
# Start by running the following cell (click inside it and then press Shift-Enter) to load some computational tools you can use.

# %%
import numpy as np
from numpy import sqrt
import matplotlib.pyplot as plt

def length(v):
    '''Return the length of v.'''
    v = np.array(v)
    return sqrt(np.sum(v * v))

def plotvectors(lst):
    '''Plot a list of 2D vectors.'''
    
    xcoords = [v[0] for v in lst]
    ycoords = [v[1] for v in lst]
    plt.quiver([0 for v in lst], [0 for v in lst], xcoords, ycoords, scale_units='xy', angles='xy', scale=1)
    maxx = max(xcoords + [0])
    minx = min(xcoords + [0])
    xrange = maxx-minx
    maxy = max(ycoords + [0])
    miny = min(ycoords + [0])
    yrange = maxy-miny
    biggerrange = max(xrange, yrange)
    
    plt.xlim(minx - (biggerrange - xrange)/2, maxx + (biggerrange - xrange)/2)
    plt.ylim(miny - (biggerrange - yrange)/2, maxy + (biggerrange - yrange)/2)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

def proj(v,w):
    '''Project vector v onto w.'''
    v = np.array(v)
    w = np.array(w)
    return np.sum(v * w)/np.sum(w * w) * w

def GramSchmidt(lst):
    '''Orthogonalize the basis given by lst.'''
    if len(lst) <= 1:
        return lst
    b1 = np.array(lst.pop(0))
    newlst = [b1]
    dim = np.shape(b1)
    for v in lst:
        projv = np.zeros(dim)
        for b in newlst:
            projv += proj(v,b)
        if not np.isclose(v-projv, np.zeros(dim)).all():
            newlst.append(v-projv)
    return newlst

def Proj(lst, v):
    '''Project v onto the subspace generated by lst.'''
    v = np.array(v)
    Projv = np.zeros(np.shape(v))
    if len(lst) == 0:
        return Projv
    for w in GramSchmidt(lst):
        w = np.array(w)
        Projv += np.sum(v * w)/np.sum(w * w) * w
    return Projv
    
def Rem(lst, v):
    '''The remainder after projecting v onto the subspace generated by lst.'''
    return v - Proj(lst, v)

# %% [markdown]
# ## Example
#
# Let's show how to project a vector

# %%
u = np.array([9,-2])
v = np.array([-16,5])
plotvectors([u,v])
# Out:
# 9.219544457292887
# 16.76305461424021

# %% [markdown]
# $u$ is shorter, so let's add copies of it to $v$. We can see below that $n=2$ gives the shortest length.

# %%
vpu = v+u
vp2u = v+2*u
vp3u = v+3*u

plotvectors([u,v,vmu,vm2u,vm3u])

print(length(vpu))
print(length(vp2u))
print(length(vp3u))
# Out:
# 7.615773105863909
# 2.23606797749979
# 11.045361017187261

# %% [markdown]
# ## Workspace
